# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
plt.rc('font', family='AppleGothic')
plt.rcParams["font.size"] = 12.
plt.rcParams['xtick.labelsize'] = 12.
plt.rcParams['ytick.labelsize'] = 12.
plt.rcParams['axes.unicode_minus'] = False

# %%
CHART_NAME = 'Histogram_sns'
cnt, PNG, UNDERBAR = 0, '.png', '_'
filename = 'welfareClean.csv'

# %%
# 파일 저장

def FileSave():
    global cnt
    cnt +=1
    savefile = CHART_NAME + UNDERBAR + str(cnt).zfill(2) + PNG
    plt.savefig(savefile, dpi = 400)
    print(savefile + '파일이 저장되었습니다.')

# %% [markdown]
# # 히스토그램 - 1차원 데이터

# %% [markdown]
# # 선분만 그리기

# %%
# data load
welfare = pd.read_csv(filename, encoding = 'CP949')
x = welfare['나이']

## 1) 선분만 그리기
fig1 = plt.figure()
plt.title('rugplot과 kde')
sns.distplot(x, rug=True, hist = False, kde = True)

# plt.show()
FileSave()
# Out:
# Histogram_sns_01.png파일이 저장되었습니다.

# %% [markdown]
# # 커널밀도곡선과 히스토그램을 동시에 그리기

# %%
# data load
welfare = pd.read_csv(filename, encoding = 'CP949')
print(welfare.columns)
print(welfare)

## 2) 커널밀도곡선과 히스토그램을 동시에 보여주기
fig2 = plt.figure()
plt.title('kde와 histogram')
sns.distplot(x, rug=False, hist = True, kde = True)

# plt.show()
FileSave()
# Out:
# Index(['성별', '생일', '결혼 유무', '종교 유무', '직업 코드', '소득', '지역구', '나이', '직업', '연령대'], dtype='object')
#       성별    생일 결혼 유무 종교 유무  직업 코드           소득           지역구  나이  \
# 0     남성  1948   무응답    없음  942.0   120.000000            서울  74
# 1     남성  1945    이혼    없음  942.0   220.200000            서울  77
# 2     남성  1946    결혼    없음  942.0   139.000000            서울  76
# 3     남성  1953    결혼    없음  942.0   150.000000            서울  69
# 4     남성  1960    결혼    있음  942.0   166.000000            서울  62
# ...   ..   ...   ...   ...    ...          ...           ...  ..
# 7524  여성  1950    결혼    있음  819.0   241.619016         강원/충북  72
# 7525  남성  1960    결혼    있음  111.0   250.000000  광주/전남/전북/제주도  62
# 7526  남성  1960    결혼    없음  111.0  1250.000000            서울  62
# 7527  남성  1992   무응답    있음  876.0   280.000000      부산/경남/울산  30
# 7528  남성  1935    결혼    있음  876.0   156.000000      부산/경남/울산  87
#
#                        직업 연령대
# 0               경비원 및 검표원  노년
# 1               경비원 및 검표원  노년
# 2               경비원 및 검표원  노년
# 3               경비원 및 검표원  노년
# 4               경비원 및 검표원  노년
# ...                   ...  ..
# 7524      기타 식품가공관련 기계조작원  노년
# 7525  의회의원 고위공무원 및 공공단체임원  노년
# 7526  의회의원 고위공무원 및 공공단체임원  노년
# 7527    선박 갑판승무원 및 관련 종사원  중년
# 7528    선박 갑판승무원 및 관련 종사원  노년
#
# [7529 rows x 10 columns]
# Histogram_sns_02.png파일이 저장되었습니다.

# %% [markdown]
# # 데이터를 가로방향으로 그리기

# %%
# data load
welfare = pd.read_csv(filename, encoding = 'CP949')
print(welfare.columns)
print(welfare)

## 3) 데이터를 가로 방향으로 그리기
fig3 = plt.figure()
plt.title('가로로 표현하기')
sns.distplot(x, vertical = True)


# plt.show()
FileSave()
# Out:
# Index(['성별', '생일', '결혼 유무', '종교 유무', '직업 코드', '소득', '지역구', '나이', '직업', '연령대'], dtype='object')
#       성별    생일 결혼 유무 종교 유무  직업 코드           소득           지역구  나이  \
# 0     남성  1948   무응답    없음  942.0   120.000000            서울  74
# 1     남성  1945    이혼    없음  942.0   220.200000            서울  77
# 2     남성  1946    결혼    없음  942.0   139.000000            서울  76
# 3     남성  1953    결혼    없음  942.0   150.000000            서울  69
# 4     남성  1960    결혼    있음  942.0   166.000000            서울  62
# ...   ..   ...   ...   ...    ...          ...           ...  ..
# 7524  여성  1950    결혼    있음  819.0   241.619016         강원/충북  72
# 7525  남성  1960    결혼    있음  111.0   250.000000  광주/전남/전북/제주도  62
# 7526  남성  1960    결혼    없음  111.0  1250.000000            서울  62
# 7527  남성  1992   무응답    있음  876.0   280.000000      부산/경남/울산  30
# 7528  남성  1935    결혼    있음  876.0   156.000000      부산/경남/울산  87
#
#                        직업 연령대
# 0               경비원 및 검표원  노년
# 1               경비원 및 검표원  노년
# 2               경비원 및 검표원  노년
# 3               경비원 및 검표원  노년
# 4               경비원 및 검표원  노년
# ...                   ...  ..
# 7524      기타 식품가공관련 기계조작원  노년
# 7525  의회의원 고위공무원 및 공공단체임원  노년
# 7526  의회의원 고위공무원 및 공공단체임원  노년
# 7527    선박 갑판승무원 및 관련 종사원  중년
# 7528    선박 갑판승무원 및 관련 종사원  노년
#
# [7529 rows x 10 columns]
# Histogram_sns_03.png파일이 저장되었습니다.

# %% [markdown]
# # 데이터의 색상을 지정하기

# %%
# data load
welfare = pd.read_csv(filename, encoding = 'CP949')
print(welfare.columns)
print(welfare)

## 색상을 지정하기
fig4 = plt.figure()
plt.title('컬러 바꾸기')
sns.distplot(x, color = 'm')

# plt.show()
FileSave()
# Out:
# Index(['성별', '생일', '결혼 유무', '종교 유무', '직업 코드', '소득', '지역구', '나이', '직업', '연령대'], dtype='object')
#       성별    생일 결혼 유무 종교 유무  직업 코드           소득           지역구  나이  \
# 0     남성  1948   무응답    없음  942.0   120.000000            서울  74
# 1     남성  1945    이혼    없음  942.0   220.200000            서울  77
# 2     남성  1946    결혼    없음  942.0   139.000000            서울  76
# 3     남성  1953    결혼    없음  942.0   150.000000            서울  69
# 4     남성  1960    결혼    있음  942.0   166.000000            서울  62
# ...   ..   ...   ...   ...    ...          ...           ...  ..
# 7524  여성  1950    결혼    있음  819.0   241.619016         강원/충북  72
# 7525  남성  1960    결혼    있음  111.0   250.000000  광주/전남/전북/제주도  62
# 7526  남성  1960    결혼    없음  111.0  1250.000000            서울  62
# 7527  남성  1992   무응답    있음  876.0   280.000000      부산/경남/울산  30
# 7528  남성  1935    결혼    있음  876.0   156.000000      부산/경남/울산  87
#
#                        직업 연령대
# 0               경비원 및 검표원  노년
# 1               경비원 및 검표원  노년
# 2               경비원 및 검표원  노년
# 3               경비원 및 검표원  노년
# 4               경비원 및 검표원  노년
# ...                   ...  ..
# 7524      기타 식품가공관련 기계조작원  노년
# 7525  의회의원 고위공무원 및 공공단체임원  노년
# 7526  의회의원 고위공무원 및 공공단체임원  노년
# 7527    선박 갑판승무원 및 관련 종사원  중년
# 7528    선박 갑판승무원 및 관련 종사원  노년
#
# [7529 rows x 10 columns]
# Histogram_sns_04.png파일이 저장되었습니다.

# %%
from matplotlib.backends.backend_pdf import PdfPages

pdfsave = PdfPages(CHART_NAME + "_19011773.pdf")
pdfsave.savefig(fig1)
pdfsave.savefig(fig2)
pdfsave.savefig(fig3)
pdfsave.savefig(fig4)
pdfsave.close()
